# %% [markdown]
# ### Load Environment

# %%
from dotenv import load_dotenv
import os
load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ### OpenAI Client

# %%
import openai
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Can you print 10 random words?"}
        ]
)
print(response.choices[0].message.content)
# Out:
# galaxy marigold sprint cobalt ripple ferret tundra lantern whisper quartz

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=489, prompt_tokens=24, total_tokens=513, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=448, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
import openai
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Can you print 10 random words?"}
        ],
        reasoning_effort="minimal"
)
print(response.choices[0].message.content)

# %%
response.usage

# %% [markdown]
# ### Google genai Client

# %%
from google import genai
gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))
response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["You are a helpful assistant","Can you print 10 random words?"]
)
print(response.text)
# Out:
# Here are 10 random words for you:
#
# 1.  **Mountain**
# 2.  **Whisper**
# 3.  **Journey**
# 4.  **Crimson**
# 5.  **Galaxy**
# 6.  **Serene**
# 7.  **Echo**
# 8.  **Vibrant**
# 9.  **Curiosity**
# 10. **Shadow**

# %% [markdown]
# ### Grok Client

# %%
from groq import Groq
groq= Groq(api_key=os.getenv("GROK_API_KEY"))
response = groq.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Can you print 10 random words?"}
        ]
)
print(response.choices[0].message.content)
